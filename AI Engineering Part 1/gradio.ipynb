# %% [markdown]
# ### Step 1: Import Libraries & API Keys

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])

client = OpenAI()
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Basic UI Interface

# %%
import gradio as gr

# %%
def respond_basic(message, history):
    return f"I'm crazy about AI! ***message:{message}***, ***history:{history}***"

# %%
#gr.ChatInterface(fn=respond_basic, type="messages").launch()
gr.ChatInterface(fn=respond_basic).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def respond_basic(message, history):
    return f"I'm crazy about AI! And I'm chatthing with you in the browser."

gr.ChatInterface(fn=respond_basic).launch(inbrowser=True,share=False)
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Step 3. Add AI Functionality

# %%
def respond_ai(message, history):
    messages = [{"role": "system", "content": "You are an  extremely unhelpful assistant."}] + history + [{"role": "user", "content": message}]
    client = OpenAI(api_key=OPENAI_API_KEY)
    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=messages
    )
    reply = response.choices[0].message.content
    return reply

gr.ChatInterface(fn=respond_ai).launch(inbrowser=True,share=False)
# Out:
# * Running on local URL:  http://127.0.0.1:7867
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7867/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
