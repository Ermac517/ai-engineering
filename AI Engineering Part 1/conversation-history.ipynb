# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")

client = OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# ### Step 2: Call the API

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Next week I'm traveling to Spain. Can you give me some tips?"},
    ],
)

reply = response.choices[0].message.content
display(Markdown(reply))

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Where am I travelling to next week?"},
    ],
)

reply = response.choices[0].message.content
display(Markdown(reply))

# %% [markdown]
# ### In theory... (doing it manually for illustration)

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Next week I'm traveling to Spain."},
    {"role": "assistant", "content": "That sounds exciting! Do you need any tips for your trip?"},
    {"role": "user", "content": "Where am I travelling to next week?"}
]

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
display(Markdown(reply))

# %% [markdown]
# ### Now: not manually

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Next week I'm traveling to Spain."}
]

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})

print(messages)

#display(Markdown(reply))

# %%
from pprint import pprint
pprint(messages)

# %%
messages.append({"role": "user", "content": "Where am I travelling to next week?"})
pprint(messages)

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
pprint(messages)

# %%
messages.append({"role": "user", "content": "What's the capital?"})

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
pprint(messages)
