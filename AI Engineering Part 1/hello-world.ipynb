# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "user", "content": "What is an okapi?"}
    ],
)

answer = response.choices[0].message.content

print(answer)
# Out:
# An okapi is a unique mammal native to the dense rainforests of the Democratic Republic of Congo in Central Africa. Despite its zebra-like stripes on its legs, it is actually more closely related to the giraffe. The okapi has a body shape similar to a giraffe but is shorter and has a much thicker neck. It has a reddish-brown coat with white horizontal stripes on its legs, which help it blend into the forest environment.
#
# Okapis are solitary, shy animals and are herbivores, feeding mainly on tree leaves, buds, grasses, ferns, fruits, and fungi. They were relatively unknown to the western world until the early 20th century, making them somewhat of a zoological mystery for many years. The okapi is sometimes referred to as the "forest giraffe" because of its close relationship to the giraffe family.
