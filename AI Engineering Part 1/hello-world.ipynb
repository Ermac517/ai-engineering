# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "user", "content": "What is an okapi?"}
    ],
)

answer = response.choices[0].message.content

print(answer)
# Out:
# An okapi is a unique and rare mammal native to the dense rainforests of the Democratic Republic of Congo in central Africa. It is the only living relative of the giraffe, and despite its zebra-like stripes on its legs, it is more closely related to giraffes than to zebras. The okapi has a velvety dark brown or reddish coat with distinctive white horizontal stripes on its upper legs and hindquarters, which help it blend into the forest environment.
#
# Okapis have long necks and large ears, adaptations that help them reach leaves and detect sounds in the forest. They are generally shy and solitary animals, feeding on leaves, buds, grasses, ferns, fruits, and fungi. The okapi is considered an important species for conservation due to its limited habitat and the threats it faces from deforestation and hunting.
